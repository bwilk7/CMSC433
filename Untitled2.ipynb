# %%
data = read.csv('~/g.csv')

# %%
library(ggplot2)

# %%
ggplot(data, aes(Weighted.Total..Total.Pts..up.to.0...445233) )+ geom_density(adjust=1/10)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# plot without title

# %%
ggplot(data, aes(Weighted.Total..Total.Pts..up.to.0...445233) ) + geom_violin()
